# %%
# !pip install numpy
# !pip install matplotlib
# !pip install scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %%
#Choosing Early Universe version of the Hubble Constant:

H_0=67

# %%
# Case 1:

def universe_1(u):
  return H_0**-1*(u**-1)**-1/2

  def uni_1(a):
            return integrate.quad(universe_1, 0, a)

# %%
def line(x):
  return 2*x

  def para(x_1):
    return integrate.quad(line, 0, x_1)

    x_min = 0
    x_max = 5
    num_points = 100

    x_values = np.linespace(x_min, x_max, num_points)
    y_values = para(x_values)

    plt.plot(x_value, y_values, label='parabola', color='darkblue')
    plt.title("Parabola")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.grid(True)
    plt.show()
